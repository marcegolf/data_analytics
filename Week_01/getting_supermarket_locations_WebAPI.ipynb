# %% [markdown]
# # Getting all available Swiss supermarkets using the overpass Web API

# %% [markdown]
# ## Libraries and settings

# %%
# Libraries
import os
import requests
import json
import folium
from pandas import json_normalize

# Ignore warnings
import warnings
warnings.filterwarnings("ignore")

# Show current working directory
print(os.getcwd())
# Out:
# /workspaces/data_analytics/Week_01

# %% [markdown]
# ## Overpass turbo query to get all available supermarkets in Switzerland

# %%
# Overpass API URL
url = 'http://overpass-api.de/api/interpreter'

# Overpass turbo query
query = f"""
        [out:json];
        area["ISO3166-1"="CH"][admin_level=2];
        node ["shop"="supermarket"](area);
        out;"""

# Web API request
r = requests.get(url, params={'data': query})
data = r.json()['elements']

# Save data to file
with open('supermarkets.json', 'w') as json_file:
    json.dump(data, json_file)

# Store data in data frame
df = json_normalize(data)

# Number of rows and columns
print(df.shape)

# First rows
df.head()
# Out:
# (3468, 277)
#    type        id        lat       lon tags.addr:city tags.addr:country  \
# 0  node  33126515  47.155616  9.037915        Schänis                CH
# 1  node  36726161  47.226191  8.980329         Uznach               NaN
# 2  node  39768209  47.225154  8.969868         Uznach               NaN
# 3  node  39947904  47.376732  8.542161         Zürich                CH
# 4  node  48932835  47.375020  8.522895         Zürich               NaN
#
#   tags.addr:housenumber tags.addr:postcode tags.addr:street tags.brand  ...  \
# 0                    32               8718   Biltnerstrasse       Spar  ...
# 1                    25               8730   Zürcherstrasse     Migros  ...
# 2                   NaN               8730              NaN       Coop  ...
# 3                     1               8001    Bahnhofbrücke       Coop  ...
# 4                     7               8004     Wengistrasse     Migros  ...
#
#   tags.source:addr tags.opening_date tags.postid tags.payment:account_cards  \
# 0              NaN               NaN         NaN                        NaN
# 1              NaN               NaN         NaN                        NaN
# 2              NaN               NaN         NaN                        NaN
# 3              NaN               NaN         NaN                        NaN
# 4              NaN               NaN         NaN                        NaN
#
#   tags.diet:mediterranean tags.diet:seafood tags.recycling:low_energy_bulbs  \
# 0                     NaN               NaN                             NaN
# 1                     NaN               NaN                             NaN
# 2                     NaN               NaN                             NaN
# 3                     NaN               NaN                             NaN
# 4                     NaN               NaN                             NaN
#
#   tags.opening_hours:cafe tags.name:zh-Hans tags.panoramax
# 0                     NaN               NaN            NaN
# 1                     NaN               NaN            NaN
# 2                     NaN               NaN            NaN
# 3                     NaN               NaN            NaN
# 4                     NaN               NaN            NaN
#
# [5 rows x 277 columns]

# %% [markdown]
# ## Plot supermarkets on map

# %%
# Subset of supermarkets by brand
locations = df[["lat", "lon", "tags.brand", "tags.shop"]].loc[df["tags.brand"].isin(['Migros', 'Coop'])]
print(locations.head(5))

# Create map
map = folium.Map(location=[locations.lat.mean(), 
                           locations.lon.mean()], 
                 zoom_start=8, 
                 control_scale=True)

# Add maker symbols
for index, location_info in locations.iterrows():
    folium.Marker([location_info["lat"], 
                   location_info["lon"]], 
                  popup=location_info["tags.brand"]).add_to(map)

# Plot map
map
# Out:
#          lat       lon tags.brand    tags.shop
# 1  47.226191  8.980329     Migros  supermarket
# 2  47.225154  8.969868       Coop  supermarket
# 3  47.376732  8.542161       Coop  supermarket
# 4  47.375020  8.522895     Migros  supermarket
# 6  47.491874  8.706448     Migros  supermarket
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_b8ae6f3adf2a4cfe62905013c6a19795 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_b8ae6f3adf2a4cfe62905013c6a19795&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_b8ae6f3adf2a4cfe62905013c6a19795 = L.map(
#                 &quot;map_b8ae6f3adf2a4cfe62905013c6a19795&quot;,
#                 {
#                     center: [47.01062440107172, 8.006166859274527],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 8,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_b8ae6f3adf2a4cfe62905013c6a19795);
#
#
#
#
#
#             var tile_layer_35f34cba238932cec3a64768864da836 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_35f34cba238932cec3a64768864da836.addTo(map_b8ae6f3adf2a4cfe62905013c6a19795);
#
#
#             var marker_4b9e8eb55eb73165da191cd9d3c1480a = L.marker(
#                 [47.2261912, 8.9803292],
#                 {}
#             ).addTo(map_b8ae6f3adf2a4cfe62905013c6a19795);
#
#
#         var popup_a0424838b9d8f8a20d2b1a8850449fbb = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_a825b0f953df884403cf461e19288a2f = $(`&lt;div id=&quot;html_a825b0f953df884403cf461e19288a2f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Migros&lt;/div&gt;`)[0];
#                 popup_a0424838b9d8f8a20d2b1a8850449fbb.setContent(html_a825b0f953df884403cf461e19288a2f);
#
#
#
#         marker_4b9e8eb55eb73165da191cd9d3c1480a.bindPopup(popup_a0424838b9d8f8a20d2b1a8850449fbb)
#         ;
#
#
#
#
#             var marker_2336d132523bc5829ec6b92ad6781904 = L.marker(
#                 [47.2251539, 8.9698681],
#                 {}
#             ).addTo(map_b8ae6f3adf2a4cfe62905013c6a19795);
#
#
#         var popup_608e5e332db2ee2145f12ea6bad94af3 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_428f441f629247237de5c50e38f00f3d = $(`&lt;div id=&quot;html_428f441f629247237de5c50e38f00f3d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Coop&lt;/div&gt;`)[0];
#                 popup_608e5e332db2ee2145f12ea6bad94af3.setContent(html_428f441f629247237de5c50e38f00f3d);
#
#
#
#         marker_2336d132523bc5829ec6b92ad6781904.bindPopup(popup_608e5e332db2ee2145f12ea6bad94af3)
#         ;
#
#
#
#
#             var marker_59df88f2c6ae7a80645c232dd37f0f28 = L.marker(
#                 [47.3767316, 8.5421608],
#                 {}
#             ).addTo(map_b8ae6f3adf2a4cfe62905013c6a19795);
#
#
#         var popup_d1e3207ed0caad305bae3148e5d9a658 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_aa2e9c5627e7629317894bbca17be70b = $(`&lt;div id=&quot;html_aa2e9c5627e7629317894bbca17be70b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Coop&lt;/div&gt;`)[0];
#                 popup_d1e3207ed0caad305bae3148e5d9a658.setContent(html_aa2e9c5627e7629317894bbca17be70b);
#
#
#
#         marker_59df88f2c6ae7a80645c232dd37f0f28.bindPopup(popup_d1e3207ed0caad305bae3148e5d9a658)
#         ;
#
#
#
#
#             var marker_e42b0393a66200b2b6e92d991a4d71d8 = L.marker(
#                 [47.37502, 8.522895],
#                 {}
#             ).addTo(map_b8ae6f3adf2a4cfe62905013c6a19795);
#
#
#         var popup_990d4cbe522cf0722ccc6ededfae2903 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_dfc69aa2ccd60042440c60f0792963c2 = $(`&lt;div id=&quot;html_dfc69aa2ccd60042440c60f0792963c2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Migros&lt;/div&gt;`)[0];
#                 popup_990d4cbe522cf0722ccc6ededfae2903.setContent(html_dfc69aa2ccd60042440c60f0792963c2);
#
#
#
#         marker_e42b0393a66200b2b6e92d991a4d71d8.bindPopup(popup_990d4cbe522cf0722ccc6ededfae2903)
#         ;
#
#
#
#
#             var marker_73fcfe2938543c8635587d5c79096ef2 = L.marker(
#                 [47.4918744, 8.7064484],
#                 {}
#             ).addTo(map_b8ae6f3adf2a4cfe62905013c6a19795);
#
#
#         var popup_8fcadc19e8c6247feba797e973947adf = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_c051ed555508ae37b26960d8306cefa1 = $(`&lt;div id=&quot;html_c051ed555508ae37b26960d8306cefa1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Migros&lt;/div&gt;`)[0];
#                 popup_8fcadc19e8c6247feba797e973947adf.setContent(html_c051ed555508ae37b26960d8306cefa1);
#
#
#
#         marker_73fcfe2938543c8635587d5c79096ef2.bindPopup(popup_8fcadc19e8c6247feba797e973947adf)
#         ;
#
#
#
#
#             var marker_3cb792120172e4e224edc6b997c7a3ef = L.marker(
#                 [47.3400698, 8.5305461],
#                 {}

# %% [markdown]
# ### Jupyter notebook --footer info-- (please always provide this at the end of each submitted notebook)

# %%
import os
import platform
import socket
from platform import python_version
from datetime import datetime

print('-----------------------------------')
print(os.name.upper())
print(platform.system(), '|', platform.release())
print('Datetime:', datetime.now().strftime("%Y-%m-%d %H:%M:%S"))
print('Python Version:', python_version())
print('-----------------------------------')
# Out:
# -----------------------------------
# POSIX
# Linux | 6.8.0-1030-azure
# Datetime: 2025-11-29 11:42:40
# Python Version: 3.11.14
# -----------------------------------
